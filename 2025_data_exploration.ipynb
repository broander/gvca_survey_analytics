# %%
import pandas as pd

df = pd.read_csv("/workspaces/gvca_survey_analytics/2024 Parent Satisfaction Survey.csv")
pd.set_option("display.max_columns", None)
display(df.head())
# Out:
#    Respondent ID  Collector ID              Start Date  \
# 0            NaN           NaN                     NaN
# 1   1.185287e+11   454577492.0  02/04/2024 06:02:54 PM
# 2   1.185287e+11   454577492.0  02/04/2024 04:15:14 PM
# 3   1.185199e+11   454577492.0  01/23/2024 03:21:16 PM
# 4   1.185283e+11   454577492.0  02/01/2024 10:13:53 PM
#
#                  End Date  IP Address  Email Address  First Name  Last Name  \
# 0                     NaN         NaN            NaN         NaN        NaN
# 1  02/04/2024 06:25:52 PM         NaN            NaN         NaN        NaN
# 2  02/04/2024 04:26:08 PM         NaN            NaN         NaN        NaN
# 3  02/04/2024 10:21:24 AM         NaN            NaN         NaN        NaN
# 4  02/03/2024 02:54:33 PM         NaN            NaN         NaN        NaN
#
#    Custom Data 1                     Choose a method of submission.  \
# 0            NaN                                           Response
# ...

# %%
for i in range(1, len(new_headers)):
    if new_headers[i][0].startswith('Unnamed'):
        new_headers[i] = (new_headers[i-1][0], new_headers[i][1], f'Column {i}')
    else:
        new_headers[i] = (new_headers[i][0], new_headers[i][1], f'Column {i}')

# Convert the updated headers to a DataFrame
headers_df = pd.DataFrame(new_headers, columns=['First Value', 'Second Value', 'Column Number'])

# Update the DataFrame with new headers
df.columns = pd.MultiIndex.from_tuples(new_headers)

# Display the updated DataFrame
display(df.head())
# Out:
#   Respondent ID Collector ID              Start Date                End Date  \
#             NaN          NaN                     NaN                     NaN
#        Column 0     Column 1                Column 2                Column 3
# 0           NaN          NaN                     NaN                     NaN
# 1  1.185287e+11  454577492.0  02/04/2024 06:02:54 PM  02/04/2024 06:25:52 PM
# 2  1.185287e+11  454577492.0  02/04/2024 04:15:14 PM  02/04/2024 04:26:08 PM
# 3  1.185199e+11  454577492.0  01/23/2024 03:21:16 PM  02/04/2024 10:21:24 AM
# 4  1.185283e+11  454577492.0  02/01/2024 10:13:53 PM  02/03/2024 02:54:33 PM
#
#   IP Address Email Address First Name Last Name Custom Data 1  \
#          NaN           NaN        NaN       NaN           NaN
#     Column 4      Column 5   Column 6  Column 7      Column 8
# 0        NaN           NaN        NaN       NaN           NaN
# 1        NaN           NaN        NaN       NaN           NaN
# ...

# %%
# Update headers using list comprehension
new_headers = [
    (new_headers[i-1][0], new_headers[i][1], f'Column {i}') if new_headers[i][0].startswith('Unnamed') or new_headers[i][0].startswith('Responses pertinent') else (new_headers[i][0], new_headers[i][1], f'Column {i}')
    for i in range(len(new_headers))
]

# Convert the updated headers to a DataFrame
headers_df = pd.DataFrame(new_headers, columns=['First Value', 'Second Value', 'Column Number'])

# Update the DataFrame with new headers
df.columns = pd.MultiIndex.from_tuples(new_headers)

# Display the updated DataFrame
display(df.head())
# Out:
#   Respondent ID Collector ID              Start Date                End Date  \
#             NaN          NaN                     NaN                     NaN
#        Column 0     Column 1                Column 2                Column 3
# 0           NaN          NaN                     NaN                     NaN
# 1  1.185287e+11  454577492.0  02/04/2024 06:02:54 PM  02/04/2024 06:25:52 PM
# 2  1.185287e+11  454577492.0  02/04/2024 04:15:14 PM  02/04/2024 04:26:08 PM
# 3  1.185199e+11  454577492.0  01/23/2024 03:21:16 PM  02/04/2024 10:21:24 AM
# 4  1.185283e+11  454577492.0  02/01/2024 10:13:53 PM  02/03/2024 02:54:33 PM
#
#   IP Address Email Address First Name Last Name Custom Data 1  \
#          NaN           NaN        NaN       NaN           NaN
#     Column 4      Column 5   Column 6  Column 7      Column 8
# 0        NaN           NaN        NaN       NaN           NaN
# 1        NaN           NaN        NaN       NaN           NaN
# ...
